# %%
import pandas as pd
directory = "C:/Users/Youngju Hong/Downloads"

# %%
data = pd.read_excel(f"{directory}/2019 고등교육기관 외국인 유학생 현황.xlsx", sheet_name = 2,header = 1)

# %%
data
# Out:
#           연도     학제                 학교명 학교상태    본분교   시도     시군구   설립     총계  \
# 0        NaN    NaN                 NaN  NaN    NaN  NaN     NaN  NaN    NaN
# 1        NaN    NaN                 NaN  NaN    NaN  NaN     NaN  NaN    NaN
# 2     2019.0    대학교             강릉원주대학교   기존     본교   강원  강원 강릉시   국립  205.0
# 3     2019.0    대학교             강릉원주대학교   기존  제2캠퍼스   강원  강원 원주시   국립    1.0
# 4     2019.0  일반대학원          강릉원주대학교대학원   기존     본교   강원  강원 강릉시   국립   56.0
# ...      ...    ...                 ...  ...    ...  ...     ...  ...    ...
# 1043  2019.0   기능대학       한국폴리텍대학 인천캠퍼스   기존     본교   인천  인천 부평구   사립    2.0
# 1044  2019.0   기능대학   한국폴리텍 IV 대학 대전캠퍼스   기존     본교   대전   대전 동구   사립    1.0
# 1045  2019.0   기능대학    한국폴리텍 Ⅵ 대학 영주캠퍼스   기존     본교   경북  경북 영주시   사립    3.0
# 1046  2019.0   기능대학       한국폴리텍대학 창원캠퍼스   기존     본교   경남  경남 창원시   사립    1.0
# 1047  2019.0   기능대학  한국폴리텍 VII 대학 울산캠퍼스   기존     본교   울산   울산 중구   사립    2.0
#
# ...

# %%
data = data[data.iloc[:,5] == "서울"]

# %%
def subset_name(univ):
    return univ[:univ.find("대학교")+3]

# %%
data["학교명"] = data["학교명"].apply(subset_name)
# Out:
# C:\Users\Youngju Hong\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#data = data.groupby("학교명")["총계"].sum().reset_index()
data = data.rename(columns = {"학교명"})
# Out:
#                학교명      총계
# 0           가톨릭대학교    63.0
# 1         감리교신학대학교    17.0
# 2         개신대학원대학교   109.0
# 3            건국대학교  2685.0
# 4            경기대학교   589.0
# ..             ...     ...
# 81        한양사이버대학교    63.0
# 82         한양여자대학교    71.0
# 83           호서대학교    10.0
# 84           홍익대학교  2067.0
# 85  횃불트리니티신학대학원대학교    74.0
#
# [86 rows x 2 columns]

# %%
univ = pd.read_csv(f"{directory}/서울시 대학 DB.csv", encoding = "cp949")

# %%
univ
# Out:
#                 키값    연도       학교종류        학교명 본분교    학교상태     설립  우편번호  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교  본교      기존     공립   NaN
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교  본교      기존     사립   NaN
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교  본교      기존     사립   NaN
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교  본교  학교명 변경     사립   NaN
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교  본교      기존     사립   NaN
# ..             ...   ...        ...        ...  ..     ...    ...   ...
# 56  BE_LiST23-0029  2013       교육대학    서울교육대학교  본교      기존     국립   NaN
# 57  BE_LiST23-0030  2013       일반대학    서울기독대학교  본교      기존     사립   NaN
# 58  BE_LiST23-0031  2013       일반대학      서울대학교  본교      기존  국립대법인   NaN
# 59  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교  본교      기존     사립   NaN
# 60  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교  본교      기존     사립   NaN
#
#                                        주소  도로명주소    행정시   행정구      행정동  \
# ...

# %%
univ = univ.merge(data, how = "inner", on = "학교명")

# %%
univ = univ[univ["총계"] >= 100]

# %%
univ
# Out:
#                 키값    연도       학교종류          학교명    본분교    학교상태     설립  우편번호  \
# 0   BE_LiST23-0034  2013       일반대학      서울시립대학교     본교      기존     공립   NaN
# 1   BE_LiST23-0036  2013       일반대학      서울여자대학교     본교      기존     사립   NaN
# 2   BE_LiST23-0037  2013  전문대학(2년제)        서일대학교     본교  학교명 변경     사립   NaN
# 4   BE_LiST23-0039  2013       일반대학       성균관대학교     본교      기존     사립   NaN
# 5   BE_LiST23-0040  2013       일반대학      성신여자대학교     본교      기존     사립   NaN
# 6   BE_LiST23-0041  2013       일반대학        세종대학교     본교      기존     사립   NaN
# 7   BE_LiST23-0042  2013       일반대학      숙명여자대학교     본교      기존     사립   NaN
# 8   BE_LiST23-0043  2013       일반대학        숭실대학교     본교      기존     사립   NaN
# 9   BE_LiST23-0045  2013       일반대학        연세대학교     본교      기존     사립   NaN
# 10  BE_LiST23-0046  2013       일반대학      이화여자대학교     본교      기존     사립   NaN
# 13  BE_LiST23-0051  2013       일반대학        총신대학교     본교      기존     사립   NaN
# ...
