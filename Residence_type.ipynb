# %%
import pandas as pd
directory = "C://Users/Youngju Hong/Downloads/서울시 주택종류별 주택 (동별) 통계.txt"

# %%
data = pd.read_table(directory, sep = "\t", header = 1); data.head()
# Out:
#      기간  자치구    동    종류별 주택수 종류별 주택수.1 종류별 주택수.2 종류별 주택수.3 종류별 주택수.4  \
# 0    기간  자치구    동         합계        주택        주택        주택        주택
# 1    기간  자치구    동         합계         계      단독주택     다가구주택      영업겸용
# 2  2015   합계   합계  2,793,244   355,039    88,163   217,616    49,260
# 3  2015  종로구   소계     43,550    13,103     7,498     4,191     1,414
# 4  2015  종로구  사직동      2,771       729       533       128        68
#
#    종류별 주택수.5 종류별 주택수.6 종류별 주택수.7  종류별 주택수.8
# 0        아파트      연립주택     다세대주택  비거주용건물내주택
# 1        아파트      연립주택     다세대주택  비거주용건물내주택
# 2  1,636,896   117,235   654,372     29,702
# 3     12,552     5,395    11,664        836
# 4      1,532        78       386         46

# %%
data = data.replace("X", 0)

# %%
data
# Out:
#        기간  자치구     동    종류별 주택수 종류별 주택수.1 종류별 주택수.2 종류별 주택수.3 종류별 주택수.4  \
# 0      기간  자치구     동         합계        주택        주택        주택        주택
# 1      기간  자치구     동         합계         계      단독주택     다가구주택      영업겸용
# 2    2015   합계    합계  2,793,244   355,039    88,163   217,616    49,260
# 3    2015  종로구    소계     43,550    13,103     7,498     4,191     1,414
# 4    2015  종로구   사직동      2,771       729       533       128        68
# ..    ...  ...   ...        ...       ...       ...       ...       ...
# 447  2015  강동구  둔촌1동      5,935         5         0         0         0
# 448  2015  강동구  둔촌2동      7,489       598        44       431       123
# 449  2015  강동구  암사1동      8,630     1,296        32     1,050       214
# 450  2015  강동구  천호2동      7,033     1,803       161     1,396       246
# 451  2015  강동구    길동     14,311       909        26       670       213
#
#      종류별 주택수.5 종류별 주택수.6 종류별 주택수.7  종류별 주택수.8
# 0          아파트      연립주택     다세대주택  비거주용건물내주택
# ...
