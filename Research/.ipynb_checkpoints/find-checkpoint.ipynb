# %%
import pandas as pd
data = list(pd.read_excel("foreign_living_population_by_dong.xlsx")["dong"])

# %%
data
# Out:
# ['가락1동',
#  '가락1동',
#  '가락2동',
#  '가락2동',
#  '가락본동',
#  '가락본동',
#  '가리봉동',
#  '가리봉동',
#  '가산동',
#  '가산동',
#  '가양1동',
#  '가양1동',
#  '가양2동',
#  '가양2동',
#  '가양3동',
#  '가양3동',
#  '가회동',
#  '가회동',
#  '갈현1동',
#  '갈현1동',
#  '갈현2동',
#  '갈현2동',
#  '강일동',
#  '강일동',
#  '개봉1동',
#  '개봉1동',
#  '개봉2동',
#  '개봉2동',
#  '개봉3동',
#  '개봉3동',
#  '개포1동',
#  '개포1동',
#  '개포2동',
#  '개포2동',
#  '개포4동',
#  '개포4동',
#  '거여1동',
#  '거여1동',
#  '거여2동',
#  '거여2동',
#  '고덕1동',
#  '고덕1동',
#  '고덕2동',
#  '고덕2동',
#  '고척1동',
#  '고척1동',
#  '고척2동',
#  '고척2동',
#  '공덕동',
#  '공덕동',
#  '공릉1동',
#  '공릉1동',
#  '공릉2동',
#  '공릉2동',
#  '공항동',
#  '공항동',
#  '광장동',
#  '광장동',
#  '광희동',
#  '광희동',
#  '교남동',
#  '교남동',
#  '구로1동',
#  '구로1동',
#  '구로2동',
#  '구로2동',
#  '구로3동',
#  '구로3동',
#  '구로4동',
#  '구로4동',
#  '구로5동',
#  '구로5동',
#  '구산동',
#  '구산동',
#  '구의1동',
#  '구의1동',
#  '구의2동',
#  '구의2동',
#  '구의3동',
#  '구의3동',
#  '군자동',
#  '군자동',
#  '금호1가동',
#  '금호1가동',
#  '금호2.3가동',
#  '금호2.3가동',
#  '금호4가동',
#  '금호4가동',
#  '길동',
#  '길동',
#  '길음1동',
#  '길음1동',
# ...
