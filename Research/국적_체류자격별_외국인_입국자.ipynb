# %%
directory = "C:\\Users\Youngju Hong\Downloads\국적_체류자격별_외국인_입국자_월간__연간__20200818172141.xlsx"
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(directory)

# %%
data = data.transpose()

# %%
#data.columns = 
data.columns = list(data.iloc[1, :])

# %%
data = data.iloc[3:, :]
data.head()
# Out:
#      체류자격별      총계   공무   사증면제   관광통과 일시취재  단기상용   단기방문 단기취업 문화예술  ...    동반  \
# 2010     계  293070  503   7515  25681    3  2752  44145  153  115  ...  3229
# 2011     계  307249  446   9229  24239    2  2566  57438  131   81  ...  3583
# 2012     계  300177  518  10849  24733   12     -  56201  194  262  ...  4160
# 2013     계  360473  526  12612  22044    5     -  73162   76   62  ...  5094
# 2014     계  407063  603  47296  23441    1     -  54904   77   82  ...  5172
#
#        재외동포    영주   결혼이민   기타  관광취업   방문취업 긴급상륙 미상 관광상륙
# 2010  15529  1192      -   87   484  70963    0  2    -
# 2011  20999  2741    783   89   798  50271    0  0    -
# 2012  19480  3928  17001  127   998  41357    -  -  168
# 2013  28587  5062  15890   72  1182  68653    -  -   57
# 2014  40802  5509  12204  118  1322  90733    -  -  106
#
# [5 rows x 41 columns]

# %%
data = data.drop(["체류자격별", "긴급상륙", "미상", "총계"], axis = 1)

# %%
plt.rc('font', family='NanumGothic')
data.plot(figsize = (20,15))
plt.show()

# %%
plt.rc('font', family='NanumGothic')
data["유학"].plot()
plt.title("외국인 유학생 추이")
plt.xlabel("연도"); plt.ylabel("단위: 명")
data["유학"].plot()
plt.savefig("fuck.jpg")

# %%
data.index
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'],
#       dtype='object')

# %%
print([i for i in range(2010,2020)])
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
