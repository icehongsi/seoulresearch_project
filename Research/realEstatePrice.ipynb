# %%
#realEstatePrice
import pandas as pd
import requests

file_dir = "/Users/hong/Downloads/"

# %%
real_estate = pd.read_csv(f"{file_dir}2019년 표준지공시지가.csv", sep = "\t", encoding = "cp949")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
real_estate
# Out:
#         일련번호    시군구   읍면동리  지번구분   본번지 부번지      시도명  시군구명             소재지  \
# 0          1  11110  10100     1     3  52    서울특별시   종로구        청운동 3-52
# 1          2  11110  10100     1     4  15    서울특별시   종로구        청운동 4-15
# 2          3  11110  10100     1     8   9    서울특별시   종로구         청운동 8-9
# 3          4  11110  10100     1    15  12    서울특별시   종로구       청운동 15-12
# 4          5  11110  10100     1    15  13    서울특별시   종로구       청운동 15-13
# ...      ...    ...    ...   ...   ...  ..      ...   ...             ...
# 499995  3913  50130  32026     1  1582   0  제주특별자치도  서귀포시    표선면 토산리 1582
# 499996  3914  50130  32026     1  1629   1  제주특별자치도  서귀포시  표선면 토산리 1629-1
# 499997  3915  50130  32026     1  1766   1  제주특별자치도  서귀포시  표선면 토산리 1766-1
# 499998  3916  50130  32026     1  1883   0  제주특별자치도  서귀포시    표선면 토산리 1883
# 499999  3917  50130  32026     1  2003   0  제주특별자치도  서귀포시    표선면 토산리 2003
#
#           지목  ...  용도지역2  이용상황        주위환경   지세명    형상명   도로교통     공시지가  \
# ...
