# %%
import pandas as pd

# %%
jiga = pd.read_csv("/Users/hong/OneDrive - ./projectfile/workload/AL_11_D167_20200728.csv", encoding = "cp949")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
jiga.head()
# Out:
#                   고유번호       법정동코드           법정동명  특수지구분코드 특수지구분명 지번  기준년도  \
# 0  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 1  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 2  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 3  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 4  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
#
#    기준월  공동주택코드  공동주택구분코드 공동주택구분명 특수지명    공동주택명    전용면적       공시가격     데이터기준일자
# 0    1       3         3      빌라  NaN  청운벽산빌리지   83.61  232000000  2020-03-09
# 1    1       3         3      빌라  NaN  청운벽산빌리지   83.61  240000000  2020-03-09
# 2    1       3         3      빌라  NaN  청운벽산빌리지  187.49  488000000  2020-03-09
# 3    1       3         3      빌라  NaN  청운벽산빌리지  152.33  432000000  2020-03-09
# 4    1       3         3      빌라  NaN  청운벽산빌리지  152.33  432000000  2020-03-09

# %%
jiga.columns
print(jiga.dtypes)
# Out:
# 고유번호          int64
# 법정동코드         int64
# 법정동명         object
# 특수지구분코드       int64
# 특수지구분명       object
# 지번           object
# 기준년도          int64
# 기준월           int64
# 공동주택코드        int64
# 공동주택구분코드      int64
# 공동주택구분명      object
# 특수지명         object
# 공동주택명        object
# 전용면적        float64
# 공시가격          int64
# 데이터기준일자      object
# dtype: object

# %%
jiga_2020 = jiga[jiga["기준년도"] == 2020]

# %%
jiga_2020
# Out:
#                          고유번호       법정동코드           법정동명  특수지구분코드 특수지구분명   지번  \
# 1764      1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반    1
# 1765      1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반    1
# 1766      1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반    1
# 1767      1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반    1
# 1768      1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반    1
# ...                       ...         ...            ...      ...    ...  ...
# 32643761  1174011000107320000  1174011000  서울특별시 강동구 강일동        1     일반  732
# 32643762  1174011000107320000  1174011000  서울특별시 강동구 강일동        1     일반  732
# 32643763  1174011000107320000  1174011000  서울특별시 강동구 강일동        1     일반  732
# 32643764  1174011000107320000  1174011000  서울특별시 강동구 강일동        1     일반  732
# 32643765  1174011000107320000  1174011000  서울특별시 강동구 강일동        1     일반  732
#
# ...
