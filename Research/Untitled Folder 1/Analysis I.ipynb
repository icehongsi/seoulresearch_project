# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
file = pd.read_excel("C://Users/Youngju Hong/Desktop/200820_dailyFinal.xls")

# %%
file.describe()
# Out:
#              adm_cd      sub350  fcenter1km     hot_usa      hot_vi  \
# count  4.240000e+02  424.000000  424.000000  424.000000  424.000000
# mean   1.113664e+06    2.745283    0.250000    0.129717    0.139151
# std    7.411488e+03    2.289089    0.433524    0.336389    0.346513
# min    1.101053e+06    0.000000    0.000000    0.000000    0.000000
# 25%    1.107070e+06    1.000000    0.000000    0.000000    0.000000
# 50%    1.114068e+06    2.000000    0.000000    0.000000    0.000000
# 75%    1.120318e+06    4.000000    0.250000    0.000000    0.000000
# max    1.125074e+06   16.000000    1.000000    1.000000    1.000000
#
#            hot_ch      hot_jp      hot_cn  univ_count    bus_stop  ...  \
# count  424.000000  424.000000  424.000000  424.000000  424.000000  ...
# mean     0.084906    0.080189    0.122642    0.563679   26.349057  ...
# std      0.279071    0.271906    0.328413    0.842546   15.193810  ...
# ...

# %%
file.dtypes
# Out:
# adm_cd                     int64
# adm_nm                    object
# sub350                     int64
# fcenter1km                 int64
# hot_usa                    int64
# hot_vi                     int64
# hot_ch                     int64
# hot_jp                     int64
# hot_cn                     int64
# univ_count                 int64
# bus_stop                   int64
# daga_percent             float64
# green_area_ratio         float64
# commercial_area_ratio    float64
# living_area_ratio        float64
# industrial_area_ratio    float64
# super_fine               float64
# fine                     float64
# celcius                  float64
# humidity                 float64
# lux                      float64
# uv                       float64
# noise                    float64
# super_fine_adj           float64
# fine_adj                 float64
# area                       int64
# green_area               float64
# commercial_area          float64
# ...

# %%
file.columns
# Out:
# Index(['adm_cd', 'adm_nm', 'sub350', 'fcenter1km', 'hot_usa', 'hot_vi',
#        'hot_ch', 'hot_jp', 'hot_cn', 'univ_count', 'bus_stop', 'daga_percent',
#        'green_area_ratio', 'commercial_area_ratio', 'living_area_ratio',
#        'industrial_area_ratio', 'super_fine', 'fine', 'celcius', 'humidity',
#        'lux', 'uv', 'noise', 'super_fine_adj', 'fine_adj', 'area',
#        'green_area', 'commercial_area', 'living_area', 'industrial_area',
#        'sum', 'department_store', 'super_fine.1', 'fine.1', 'celcius.1',
#        'humidity.1', 'lux.1', 'uv.1', 'noise.1', 'super_fine_adj.1',
#        'fine_adj.1', 'deadly_accident', 'hospital', 'general_hospital',
#        'fire_frequency_2019', 'bank_sum'],
#       dtype='object')

# %%
file[['hot_usa', 'hot_vi','hot_ch', 'hot_jp', 'hot_cn']] = \
file[['hot_usa', 'hot_vi','hot_ch', 'hot_jp', 'hot_cn']].astype("category")

# %%
file.head()
# Out:
#     adm_cd adm_nm  sub350  fcenter1km hot_usa hot_vi hot_ch hot_jp hot_cn  \
# 0  1101053    사직동       3           1       0      0      0      0      1
# 1  1101054    삼청동       1           1       0      0      0      0      0
# 2  1101055    부암동       0           0       0      0      0      0      0
# 3  1101056    평창동       0           0       0      0      0      0      0
# 4  1101057    무악동       1           0       0      0      0      1      0
#
#    univ_count  ...        lux.1      uv.1    noise.1  super_fine_adj.1  \
# 0           1  ...  1383.743408  0.243624  47.866898          1.881106
# 1           1  ...  8655.625000  1.269119  45.810528          4.328655
# 2           1  ...  6800.470215  0.889899  46.255451         16.081945
# 3           2  ...  6698.752441  1.140742  49.146179          1.753297
# 4           1  ...  7291.489746  0.839217  48.383129         12.947498
#
#    fine_adj.1  deadly_accident  hospital  general_hospital  \
# ...

# %%
# Out:
#       adm_cd adm_nm  sub350  fcenter1km hot_usa hot_vi hot_ch hot_jp hot_cn  \
# 0    1101053    사직동       3           1       0      0      0      0      1
# 1    1101054    삼청동       1           1       0      0      0      0      0
# 2    1101055    부암동       0           0       0      0      0      0      0
# 3    1101056    평창동       0           0       0      0      0      0      0
# 4    1101057    무악동       1           0       0      0      0      1      0
# ..       ...    ...     ...         ...     ...    ...    ...    ...    ...
# 419  1125070   둔촌1동       2           1       0      0      0      0      0
# 420  1125071   둔촌2동       2           1       0      0      0      0      0
# 421  1125072   암사1동       2           0       0      0      0      0      0
# 422  1125073   천호2동       3           1       0      0      0      0      0
# 423  1125074     길동       3           1       0      0      0      0      0
#
# ...
