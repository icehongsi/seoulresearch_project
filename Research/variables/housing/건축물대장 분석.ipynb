# %%
import pandas as pd

# %%
data = pd.read_table("C:\\Users\Youngju Hong\Downloads\국토교통부_건축물대장_기본개요(2020년+06월)_분할파일\mart_djy_01.txt", encoding = "cp949", sep = "|")
# Out:
# C:\Users\Youngju Hong\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (11,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    30170-37623   30170-4543    2  집합  4  전유부    대전광역시 서구 변동 81-12번지  \
# 0  30170-39388  30170-10013  2.0  집합  4  전유부   대전광역시 서구 도마동 113-7번지
# 1  30170-39812  30170-10066  2.0  집합  4  전유부  대전광역시 서구 도마동 148-25번지
# 2  30170-41155  30170-10129  2.0  집합  4  전유부  대전광역시 서구 도마동 191-13번지
# 3  30170-53820  30170-14929  2.0  집합  4  전유부    대전광역시 서구 탄방동 86-9번지
# 4  30170-53821  30170-14929  2.0  집합  4  전유부    대전광역시 서구 탄방동 86-9번지
#
#     대전광역시 서구 배재로220번길 19 Unnamed: 8  30170  ...  0.2    19  0.3  Unnamed: 23  \
# 0        대전광역시 서구 배재로 94      무궁화연립  30170  ...  0.0  94.0  0.0          NaN
# 1      대전광역시 서구 제비네6길 74       도산빌라  30170  ...  0.0  74.0  0.0          NaN
# 2       대전광역시 서구 도림2길 23        NaN  30170  ...  0.0  23.0  0.0          NaN
# 3   대전광역시 서구 계룡로629번길 43        NaN  30170  ...  0.0  43.0  0.0          NaN
# 4   대전광역시 서구 계룡로629번길 43        NaN  30170  ...  0.0  43.0  0.0          NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26  Unnamed: 27  Unnamed: 28  20100619
# ...
